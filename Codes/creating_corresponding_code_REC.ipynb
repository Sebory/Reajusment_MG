# %%
def change_code():
    df_MG_Rec.loc[df_MG_Rec[8] == "715353",9] = "1"
    df_MG_Rec.loc[df_MG_Rec[8] == "715354",9] = "2"
    df_MG_Rec.loc[df_MG_Rec[8] == "715355",9] = "3"
    df_MG_Rec.loc[df_MG_Rec[8] == "715359",9] = "4"
    df_MG_Rec.loc[df_MG_Rec[8] == "715358",9] = "5"
    df_MG_Rec.loc[df_MG_Rec[8] == "715356",9] = "6"
    df_MG_Rec.loc[df_MG_Rec[8] == "715357",9] = "7"
    df_MG_Rec.loc[df_MG_Rec[8] == "715360",9] = "8"
    df_MG_Rec.loc[df_MG_Rec[8] == "715362",9] = "9"
    df_MG_Rec.loc[df_MG_Rec[8] == "715366",9] = "10"
    df_MG_Rec.loc[df_MG_Rec[8] == "715364",9] = "11"
    df_MG_Rec.loc[df_MG_Rec[8] == "715368",9] = "12"
    df_MG_Rec.loc[df_MG_Rec[8] == "717325",9] = "13"
    df_MG_Rec.loc[df_MG_Rec[8] == "717256",9] = "14"
    df_MG_Rec.loc[df_MG_Rec[8] == "717289",9] = "15"
    df_MG_Rec.loc[df_MG_Rec[8] == "717291",9] = "16"
    df_MG_Rec.loc[df_MG_Rec[8] == "717296",9] = "17"
    df_MG_Rec.loc[df_MG_Rec[8] == "717300",9] = "18"
    df_MG_Rec.loc[df_MG_Rec[8] == "717302",9] = "19"
    df_MG_Rec.loc[df_MG_Rec[8] == "717308",9] = "20"
    df_MG_Rec.loc[df_MG_Rec[8] == "717309",9] = "21"
    df_MG_Rec.loc[df_MG_Rec[8] == "717310",9] = "22"
    df_MG_Rec.loc[df_MG_Rec[8] == "717311",9] = "23"
    df_MG_Rec.loc[df_MG_Rec[8] == "717312",9] = "24"
    df_MG_Rec.loc[df_MG_Rec[8] == "717314",9] = "25"
    df_MG_Rec.loc[df_MG_Rec[8] == "717315",9] = "26"
    df_MG_Rec.loc[df_MG_Rec[8] == "717317",9] = "27"
    df_MG_Rec.loc[df_MG_Rec[8] == "717316",9] = "28"
    df_MG_Rec.loc[df_MG_Rec[8] == "717318",9] = "29"
    df_MG_Rec.loc[df_MG_Rec[8] == "717319",9] = "30"
    df_MG_Rec.loc[df_MG_Rec[8] == "464561",9] = "31"
    df_MG_Rec.loc[df_MG_Rec[8] == "717320",9] = "32"
    df_MG_Rec.loc[df_MG_Rec[8] == "717321",9] = "33"
    df_MG_Rec.loc[df_MG_Rec[8] == "464568",9] = "34"
    df_MG_Rec.loc[df_MG_Rec[8] == "717322",9] = "35"
    df_MG_Rec.loc[df_MG_Rec[8] == "717323",9] = "36"
    df_MG_Rec.loc[df_MG_Rec[8] == "717324",9] = "37"
    df_MG_Rec.loc[df_MG_Rec[8] == "717326",9] = "38"
    df_MG_Rec.loc[df_MG_Rec[8] == "717328",9] = "39"
    df_MG_Rec.loc[df_MG_Rec[8] == "717327",9] = "40"
    df_MG_Rec.loc[df_MG_Rec[8] == "717329",9] = "41"
    df_MG_Rec.loc[df_MG_Rec[8] == "717330",9] = "42"
    df_MG_Rec.loc[df_MG_Rec[8] == "717331",9] = "43"
    df_MG_Rec.loc[df_MG_Rec[8] == "717332",9] = "44"
    df_MG_Rec.loc[df_MG_Rec[8] == "715361",9] = "45"
    df_MG_Rec.loc[df_MG_Rec[8] == "717333",9] = "46"
    df_MG_Rec.loc[df_MG_Rec[8] == "717334",9] = "47"
    df_MG_Rec.loc[df_MG_Rec[8] == "717335",9] = "148"
    df_MG_Rec.loc[df_MG_Rec[8] == "717336",9] = "49"
    df_MG_Rec.loc[df_MG_Rec[8] == "711433",9] = "50"
    df_MG_Rec.loc[df_MG_Rec[8] == "464570",9] = "51"
    df_MG_Rec.loc[df_MG_Rec[8] == "711434",9] = "52"
    df_MG_Rec.loc[df_MG_Rec[8] == "466424",9] = "53"
    df_MG_Rec.loc[df_MG_Rec[8] == "711437",9] = "54"
    df_MG_Rec.loc[df_MG_Rec[8] == "577017",9] = "55"
    df_MG_Rec.loc[df_MG_Rec[8] == "711435",9] = "56"
    df_MG_Rec.loc[df_MG_Rec[8] == "711436",9] = "57"
    df_MG_Rec.loc[df_MG_Rec[8] == "711438",9] = "58"
    df_MG_Rec.loc[df_MG_Rec[8] == "711447",9] = "59"
    df_MG_Rec.loc[df_MG_Rec[8] == "711439",9] = "60"
    df_MG_Rec.loc[df_MG_Rec[8] == "466434",9] = "61"
    df_MG_Rec.loc[df_MG_Rec[8] == "711441",9] = "62"
    df_MG_Rec.loc[df_MG_Rec[8] == "711442",9] = "63"
    df_MG_Rec.loc[df_MG_Rec[8] == "577015",9] = "64"
    df_MG_Rec.loc[df_MG_Rec[8] == "674769",9] = "65"
    df_MG_Rec.loc[df_MG_Rec[8] == "577111",9] = "67"
    df_MG_Rec.loc[df_MG_Rec[8] == "577078",9] = "68"
    df_MG_Rec.loc[df_MG_Rec[8] == "674760",9] = "69"
    df_MG_Rec.loc[df_MG_Rec[8] == "797285",9] = "70"
    df_MG_Rec.loc[df_MG_Rec[8] == "799132",9] = "71"
    df_MG_Rec.loc[df_MG_Rec[8] == "577010",9] = "72"
    df_MG_Rec.loc[df_MG_Rec[8] == "980703",9] = "73"
    df_MG_Rec.loc[df_MG_Rec[8] == "799136",9] = "74"
    df_MG_Rec.loc[df_MG_Rec[8] == "674762",9] = "75"
    df_MG_Rec.loc[df_MG_Rec[8] == "799137",9] = "76"
    df_MG_Rec.loc[df_MG_Rec[8] == "799147",9] = "77"
    df_MG_Rec.loc[df_MG_Rec[8] == "730750",9] = "78"
    df_MG_Rec.loc[df_MG_Rec[8] == "980699",9] = "79"
